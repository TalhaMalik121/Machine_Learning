# %% [markdown]
# # 🐋 Learn Seaborn - Step-by-Step

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load sample dataset
tips = sns.load_dataset("tips")
￼Click to add a cell.
PraticingNUMPY.ipynb
PracticingPANDAS.ipynb
LearningMATPLOTLIB.ipynb
LearningSEABORN_FULL.ipynb
￼

 
# Show the first few rows
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### 1️⃣ Basic Scatter Plot

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Total Bill vs Tip")
plt.show()

# %% [markdown]
# ### 2️⃣ Scatter Plot with Hue

# %%
plt.figure(figsize=(6, 4))
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips)
plt.title("Total Bill vs Tip (colored by sex)")
plt.show()

# %% [markdown]
# ### 3️⃣ Histogram (distribution plot)

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=tips, x='total_bill', bins=20, kde=True)
plt.title("Distribution of Total Bill")
plt.show()

# %% [markdown]
# ### 4️⃣ Box Plot

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title("Boxplot of Total Bill by Day")
plt.show()

# %% [markdown]
# ### 5️⃣ Violin Plot

# %%
plt.figure(figsize=(6, 4))
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title("Violin Plot of Total Bill by Day")
plt.show()

# %% [markdown]
# ### 6️⃣ Bar Plot

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='day', y='tip', data=tips, estimator=sum)
plt.title("Total Tips by Day")
plt.show()

# %% [markdown]
# ### 7️⃣ Count Plot (like a bar plot of counts)

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='day', data=tips)
plt.title("Count of Records per Day")
plt.show()

# %% [markdown]
# ### 8️⃣ Heatmap (correlation matrix)

# %%
plt.figure(figsize=(8, 6))
corr = tips.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ### 9️⃣ Pairplot (scatter matrix)

# %%
sns.pairplot(tips, hue='sex')
plt.suptitle("Pairplot of Tips Dataset", y=1.02)#y=1.02 for tilt the title slightly above the plot for clear visualization
plt.show()
